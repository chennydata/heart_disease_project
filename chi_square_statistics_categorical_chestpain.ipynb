# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats

# %%
heart_data=pd.read_csv('Desktop/uci_data/heart.csv')

# %%
heart_data['sex']=heart_data['sex'].replace([0,1],['female','male'])
heart_data['cp']=heart_data['cp'].replace([0,1,2,3],['typical angina', 'atypical angina', 'non-anginal pain', 'no pain'])
heart_data['target']=heart_data['target'].replace([0,1],['not at risk', 'at risk'])
heart_data['fbs']=heart_data['fbs'].replace([0,1],['normal','fast blood'])
heart_data['slope']=heart_data['slope'].replace([0,1,2], ['upsloping', 'flat', 'downsloping'])
heart_data['restecg']=heart_data['restecg'].replace([0,1],['False','True'])
heart_data['exang']=heart_data['exang'].replace([0,1],['False','True'])
heart_data['thal']=heart_data['thal'].replace([1,2,3], ['normal', 'fixed detect','reversable detect'])

# %%
heart_data.head()
# Out:
#    age     sex                cp  trestbps  chol         fbs restecg  thalach  \
# 0   63    male           no pain       145   233  fast blood   False      150
# 1   37    male  non-anginal pain       130   250      normal    True      187
# 2   41  female   atypical angina       130   204      normal   False      172
# 3   56    male   atypical angina       120   236      normal    True      178
# 4   57  female    typical angina       120   354      normal    True      163
#
#    exang  oldpeak        slope  ca          thal   target
# 0  False      2.3    upsloping   0        normal  at risk
# 1  False      3.5    upsloping   0  fixed detect  at risk
# 2  False      1.4  downsloping   0  fixed detect  at risk
# 3  False      0.8  downsloping   0  fixed detect  at risk
# 4   True      0.6  downsloping   0  fixed detect  at risk

# %%
new_data = heart_data[['sex','cp','target']]
table1 = pd.pivot_table(new_data, index='sex', columns=['cp','target'], aggfunc=len, fill_value=0)
table1['total']=table1.sum(axis=1)
table1.loc['total']=table1.sum(axis=0)

# %%
table1
# Out:
# cp     atypical angina             no pain             non-anginal pain  \
# target         at risk not at risk at risk not at risk          at risk
# sex
# female              16           2       4           0               34
# male                25           7      12           7               35
# total               41           9      16           7               69
#
# cp                 typical angina             total
# target not at risk        at risk not at risk
# sex
# female           1             18          21    96
# male            17             21          83   207
# total           18             39         104   303

# %%
sex = [ [ 16,2,4,0,34,1,18,21 ], [ 25,7,12,7,35,17,21,83 ] ]
chi2, p, ddof, expected = scipy.stats.chi2_contingency( sex )
msg = "Test Statistic: {}\np-value: {}\nDegrees of Freedom: {}\n"
print( msg.format( chi2, p, ddof ) )
print( expected )
# Out:
# Test Statistic: 30.6296157688963
# p-value: 7.275298391921926e-05
# Degrees of Freedom: 7
#
# [[12.99009901  2.85148515  5.06930693  2.21782178 21.86138614  5.7029703
#   12.35643564 32.95049505]
#  [28.00990099  6.14851485 10.93069307  4.78217822 47.13861386 12.2970297
#   26.64356436 71.04950495]]

# %%
# the assumption is chest pain type has no effect on being susceptible to being targeted
# the assumption is obviously rejected
